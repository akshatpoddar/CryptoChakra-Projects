# %%
# !pip3 install pandas numpy matplotlib statsmodels scikit-learn xgboost requests coinmetrics-api-client tensorflow --break-system-packages
# Out:
# Requirement already satisfied: pandas in ./crypto-env/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: numpy in ./crypto-env/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: matplotlib in ./crypto-env/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: statsmodels in ./crypto-env/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: scikit-learn in ./crypto-env/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: xgboost in ./crypto-env/lib/python3.10/site-packages (3.0.2)
# Requirement already satisfied: requests in ./crypto-env/lib/python3.10/site-packages (2.32.4)
# Requirement already satisfied: coinmetrics-api-client in ./crypto-env/lib/python3.10/site-packages (2025.5.6.13)
# Requirement already satisfied: tensorflow in ./crypto-env/lib/python3.10/site-packages (2.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./crypto-env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./crypto-env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./crypto-env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./crypto-env/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in ./crypto-env/lib/python3.10/site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: patsy>=0.5.6 in ./crypto-env/lib/python3.10/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: joblib>=1.2.0 in ./crypto-env/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./crypto-env/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./crypto-env/lib/python3.10/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./crypto-env/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./crypto-env/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./crypto-env/lib/python3.10/site-packages (from requests) (2025.6.15)
# Requirement already satisfied: orjson<4.0.0,>=3.6.0 in ./crypto-env/lib/python3.10/site-packages (from coinmetrics-api-client) (3.10.18)
# Requirement already satisfied: polars<2.0.0,>=1.0.0 in ./crypto-env/lib/python3.10/site-packages (from coinmetrics-api-client) (1.31.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in ./crypto-env/lib/python3.10/site-packages (from coinmetrics-api-client) (4.67.1)
# Requirement already satisfied: typer>=0.7.0 in ./crypto-env/lib/python3.10/site-packages (from coinmetrics-api-client) (0.16.0)
# Requirement already satisfied: websocket-client<2.0.0,>=1.6.0 in ./crypto-env/lib/python3.10/site-packages (from coinmetrics-api-client) (1.8.0)
# Requirement already satisfied: six>=1.5 in ./crypto-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: setuptools in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (80.3.1)
# Requirement already satisfied: termcolor>=1.1.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./crypto-env/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in ./crypto-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./crypto-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./crypto-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./crypto-env/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in ./crypto-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in ./crypto-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in ./crypto-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in ./crypto-env/lib/python3.10/site-packages (from typer>=0.7.0->coinmetrics-api-client) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./crypto-env/lib/python3.10/site-packages (from typer>=0.7.0->coinmetrics-api-client) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./crypto-env/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./crypto-env/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./crypto-env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./crypto-env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels
import sklearn
import requests
from coinmetrics.api_client import CoinMetricsClient
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
from scipy.special import inv_boxcox
from scipy.stats import boxcox

# %%
client = CoinMetricsClient()
catalog_response = client.catalog_asset_metrics_v2("btc").to_list()
metric_names = [catalog_response[0]['metrics'][i]['metric'] for i in range(len(catalog_response[0]['metrics']))]
 # asset_metrics = client.get_asset_metrics(
 #            assets="btc",
 #            metrics=metric_names,
 #            frequency="1b",
 #            paging_from=PagingFrom.START,
 #            page_size=1000
 #        )

# %% [markdown]
# ## Data Source Information
#
# Data has been downloaded from: https://www.kaggle.com/datasets/mczielinski/bitcoin-historical-data/data
# This data is the very latest and up to date and is updated daily by a scraper: https://github.com/mczielinski/kaggle-bitcoin/
# This dataset contains per minute OHLCV data for BTC from Jan 2012 - Present.
# The scraper uses Bitstamp API to fetch this data. **Bitstamp** is known to be a very reliable and secure crypto exchange platform. Hence, we can consider this to be a good data source for our use case.

# %%
data = pd.read_csv('btcusd_1-min_data.csv')
data.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0

# %%
df = pd.DataFrame(data)
df.info()

print("Summary statistics")
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7085971 entries, 0 to 7085970
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
# dtypes: float64(6)
# memory usage: 324.4 MB
# Summary statistics
#           Timestamp          Open          High           Low         Close  \
# count  7.085971e+06  7.085971e+06  7.085971e+06  7.085971e+06  7.085971e+06
# mean   1.537993e+09  1.832537e+04  1.833245e+04  1.831807e+04  1.832537e+04
# std    1.227350e+08  2.553689e+04  2.554480e+04  2.552879e+04  2.553686e+04
# min    1.325412e+09  3.800000e+00  3.800000e+00  3.800000e+00  3.800000e+00
# 25%    1.431702e+09  4.292200e+02  4.294300e+02  4.290100e+02  4.292200e+02
# 50%    1.537991e+09  6.730220e+03  6.734020e+03  6.726590e+03  6.730200e+03
# 75%    1.644281e+09  2.818100e+04  2.819000e+04  2.817200e+04  2.818100e+04
# max    1.750640e+09  1.119930e+05  1.120000e+05  1.119670e+05  1.119750e+05
#
#              Volume
# count  7.085971e+06
# mean   5.253670e+00
# std    2.240655e+01
# min    0.000000e+00
# 25%    1.794391e-02
# 50%    4.562457e-01
# 75%    3.000000e+00
# max    5.853852e+03

# %%
missing_values = df.isnull().sum()
print("Count of missing values per column: ")
missing_values
# Out:
# Count of missing values per column:
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64

# %%
# Convert Timestamp format to datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
df.tail()
# Out:
#                   Timestamp      Open      High       Low     Close     Volume
# 7085966 2025-06-23 00:47:00  101285.0  101355.0  101285.0  101355.0   2.904749
# 7085967 2025-06-23 00:48:00  101355.0  101641.0  101355.0  101586.0  10.221699
# 7085968 2025-06-23 00:49:00  101644.0  101644.0  101491.0  101491.0   1.670460
# 7085969 2025-06-23 00:50:00  101452.0  101452.0  101294.0  101294.0   0.777038
# 7085970 2025-06-23 00:51:00  101341.0  101357.0  101313.0  101314.0   0.392344

# %% [markdown]
# ### Resample Data to get daily, monthly and annual dataframes

# %%
df_daily = df.resample('D', on='Timestamp').mean()

plt.figure(figsize=(10, 4))
plt.plot(df_daily['Close'], label='Close Price')
plt.title('Bitcoin Price Over Time (Days)')
plt.legend()

# %%
df_monthly = df.resample('ME', on='Timestamp').mean()

plt.figure(figsize=(10, 4))
plt.plot(df_monthly['Close'], label='Close Price')
plt.title('Bitcoin Price Over Time (Months)')
plt.legend()

# %%
df_annual = df.resample('YE-DEC', on='Timestamp').mean()

plt.figure(figsize=(10, 4))
plt.plot(df_annual['Close'], label='Close Price')
plt.title('Bitcoin Price Over Time (Years)')
plt.legend()

# %% [markdown]
# ## Feature Engineering
#
# List of features used:
# - Close Price
# - OHCLV Lags over multiple time periods
# - Simple Moving Averages over multiple time periods
# - Exponential Moving Averages over multiple time periods
# - Relative Strength Index
# - Moving Average Convergence Divergence
# - Fibonacci Retracement Levels
# - On-Balance Volume
#
# List of features that could be added:
# - historical volatility data from Volatility index
# - on-chain metrics like hashing rate, mining difficulty, etc.

# %%
df_features = df_daily[['Close']].copy()

lags = {
    "Close": [1, 3, 7, 14],
    "Open": [1, 3, 7],
    "Volume": [1, 3, 7],
    "High": [1, 3, 7],
    "Low": [1, 3, 7],
}

def create_feature_lags():
    for (key, values) in lags.items():
        for val in values: 
            col_name = f"{key}_lag_{val}"
            df_features[col_name] = df_daily[key].shift(val)
create_feature_lags()
df_features.columns
# Out:
# Index(['Close', 'Close_lag_1', 'Close_lag_3', 'Close_lag_7', 'Close_lag_14',
#        'Open_lag_1', 'Open_lag_3', 'Open_lag_7', 'Volume_lag_1',
#        'Volume_lag_3', 'Volume_lag_7', 'High_lag_1', 'High_lag_3',
#        'High_lag_7', 'Low_lag_1', 'Low_lag_3', 'Low_lag_7'],
#       dtype='object')

# %%
moving_averages = {
    "SMA" : [1, 7, 14, 30],
    "EMA" : [1, 7, 14, 30]
}

def create_feature_moving_averages():
    for (key, values) in moving_averages.items():
        for val in values:
            col_name = f"{key}_{val}"
            match key:
                case "SMA":
                    df_features[col_name] = df_daily['Close'].rolling(window=val).mean()
                case "EMA": 
                    df_features[col_name] = df_daily['Close'].ewm(span=val, adjust=False).mean()
create_feature_moving_averages()
df_features.columns
# Out:
# Index(['Close', 'Close_lag_1', 'Close_lag_3', 'Close_lag_7', 'Close_lag_14',
#        'Open_lag_1', 'Open_lag_3', 'Open_lag_7', 'Volume_lag_1',
#        'Volume_lag_3', 'Volume_lag_7', 'High_lag_1', 'High_lag_3',
#        'High_lag_7', 'Low_lag_1', 'Low_lag_3', 'Low_lag_7', 'SMA_1', 'SMA_7',
#        'SMA_14', 'SMA_30', 'EMA_1', 'EMA_7', 'EMA_14', 'EMA_30'],
#       dtype='object')

# %%
def compute_rsi(df, window=14):
    delta = df['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    df_features['RSI'] = rsi
    return df

compute_rsi(df_daily)
df_features.columns
# Out:
# Index(['Close', 'Close_lag_1', 'Close_lag_3', 'Close_lag_7', 'Close_lag_14',
#        'Open_lag_1', 'Open_lag_3', 'Open_lag_7', 'Volume_lag_1',
#        'Volume_lag_3', 'Volume_lag_7', 'High_lag_1', 'High_lag_3',
#        'High_lag_7', 'Low_lag_1', 'Low_lag_3', 'Low_lag_7', 'SMA_1', 'SMA_7',
#        'SMA_14', 'SMA_30', 'EMA_1', 'EMA_7', 'EMA_14', 'EMA_30', 'RSI'],
#       dtype='object')

# %%
def compute_macd(df, fast=12, slow=26, signal=9):
    df_features['EMA_fast'] = df['Close'].ewm(span=fast, adjust=False).mean()
    df_features['EMA_slow'] = df['Close'].ewm(span=slow, adjust=False).mean()
    df_features['MACD'] = df_features['EMA_fast'] - df_features['EMA_slow']
    df_features['Signal_Line'] = df_features['MACD'].ewm(span=signal, adjust=False).mean()
    df_features['MACD_Hist'] = df_features['MACD'] - df_features['Signal_Line']
    return df

compute_macd(df_daily)
df_features.columns
# Out:
# Index(['Close', 'Close_lag_1', 'Close_lag_3', 'Close_lag_7', 'Close_lag_14',
#        'Open_lag_1', 'Open_lag_3', 'Open_lag_7', 'Volume_lag_1',
#        'Volume_lag_3', 'Volume_lag_7', 'High_lag_1', 'High_lag_3',
#        'High_lag_7', 'Low_lag_1', 'Low_lag_3', 'Low_lag_7', 'SMA_1', 'SMA_7',
#        'SMA_14', 'SMA_30', 'EMA_1', 'EMA_7', 'EMA_14', 'EMA_30', 'RSI',
#        'EMA_fast', 'EMA_slow', 'MACD', 'Signal_Line', 'MACD_Hist'],
#       dtype='object')

# %%
def compute_bollinger_bands(df, window=20):
    sma = df['Close'].rolling(window).mean()
    std = df['Close'].rolling(window).std()
    df_features['BB_Middle'] = sma
    df_features['BB_Upper'] = sma + 2 * std
    df_features['BB_Lower'] = sma - 2 * std
    return df

compute_bollinger_bands(df_daily)
df_features.columns
# Out:
# Index(['Close', 'Close_lag_1', 'Close_lag_3', 'Close_lag_7', 'Close_lag_14',
#        'Open_lag_1', 'Open_lag_3', 'Open_lag_7', 'Volume_lag_1',
#        'Volume_lag_3', 'Volume_lag_7', 'High_lag_1', 'High_lag_3',
#        'High_lag_7', 'Low_lag_1', 'Low_lag_3', 'Low_lag_7', 'SMA_1', 'SMA_7',
#        'SMA_14', 'SMA_30', 'EMA_1', 'EMA_7', 'EMA_14', 'EMA_30', 'RSI',
#        'EMA_fast', 'EMA_slow', 'MACD', 'Signal_Line', 'MACD_Hist', 'BB_Middle',
#        'BB_Upper', 'BB_Lower'],
#       dtype='object')

# %%
def compute_obv(df):
    obv = [0]
    for i in range(1, len(df)):
        if df['Close'].iloc[i] > df['Close'].iloc[i - 1]:
            obv.append(obv[-1] + df['Volume'].iloc[i])
        elif df['Close'].iloc[i] < df['Close'].iloc[i - 1]:
            obv.append(obv[-1] - df['Volume'].iloc[i])
        else:
            obv.append(obv[-1])
    df_features['OBV'] = obv
    return df

compute_obv(df_daily)
df_features.columns
# Out:
# Index(['Close', 'Close_lag_1', 'Close_lag_3', 'Close_lag_7', 'Close_lag_14',
#        'Open_lag_1', 'Open_lag_3', 'Open_lag_7', 'Volume_lag_1',
#        'Volume_lag_3', 'Volume_lag_7', 'High_lag_1', 'High_lag_3',
#        'High_lag_7', 'Low_lag_1', 'Low_lag_3', 'Low_lag_7', 'SMA_1', 'SMA_7',
#        'SMA_14', 'SMA_30', 'EMA_1', 'EMA_7', 'EMA_14', 'EMA_30', 'RSI',
#        'EMA_fast', 'EMA_slow', 'MACD', 'Signal_Line', 'MACD_Hist', 'BB_Middle',
#        'BB_Upper', 'BB_Lower', 'OBV'],
#       dtype='object')

# %% [markdown]
# ## Model Building I: ARIMA

# %%
target = 'Close'

# %% [markdown]
# ### Step 1: Test for stationarity with ADF

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df_features[target])
print(f'p-value: {result[1]}')  # p < 0.05 = stationary
# Out:
# p-value: 0.9491023887769414

# %% [markdown]
# There is a clear upward trend and the p-value is above 0.5 indicating that the data is not stationary, so we apply level 1 differencing and check again.

# %%
df_features['Close_diff_1'] = df_features['Close'].diff()
result = adfuller(df_features['Close_diff_1'].dropna())

print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")

plt.figure(figsize=(10, 4))
plt.plot(df_features['Close_diff_1'], label='Close Price Diff 1')
plt.title('Bitcoin Price Over Time')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -10.186156679479723
# p-value: 6.5005624143410276e-18

# %% [markdown]
# The p-value is much lower than 0.5 confirming that the data is now stationary. Now we know that the mean is stabilized for this data, time to apply boxcox to the closing diff to make the variance stable as well.

# %%
# Apply Box-Cox transformation
boxcox_transformed, lambda_bc = boxcox(df_features['Close'])

# Fill the transformed series back into the DataFrame
df_features['BoxCox_Close'] = np.nan  # Initialize with NaN
df_features.loc[df_features.index, 'BoxCox_Close'] = boxcox_transformed
df_features['BoxCox_Close'].dropna()
# Difference for stationarity
df_features['BoxCox_Close_diff_1'] = df_features['BoxCox_Close'].diff()

print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")

plt.figure(figsize=(10, 4))
plt.plot(df_features['BoxCox_Close_diff_1'], label='BoxCox Close Price Diff 1')
plt.title('Bitcoin Price Over Time')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -20.734327282662953
# p-value: 0.0

# %% [markdown]
# ### Step 2: Finding p and q values for the AR and MA parameters of ARIMA using PACF and ACF graphs

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Drop NaNs from differencing
boxcox_diff = df_features['BoxCox_Close_diff_1'].dropna()

plt.figure(figsize=(14, 6))

# ACF Plot (for MA -> q)
plt.subplot(1, 2, 1)
plot_acf(boxcox_diff, lags=40, ax=plt.gca())
plt.title("ACF - Identify MA (q)")

# PACF Plot (for AR -> p)
plt.subplot(1, 2, 2)
plot_pacf(boxcox_diff, lags=40, method='ywm', ax=plt.gca())
plt.title("PACF - Identify AR (p)")

plt.tight_layout()
plt.show()

# %% [markdown]
# We see only one significant spike at t=1 and thus our p=q=1

# %% [markdown]
# ### Step 3: Split training and testing data (80/20)

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

p = 1
q = 1
d = 1

data = boxcox_diff

train_fraction = 0.8
train_len = int(train_fraction * len(data))
train = data.iloc[:train_len]
test = data.iloc[train_len:]

# %% [markdown]
# ### Step 4: Train the model and predict on test data

# %%
model = ARIMA(train, order=(p, d, q))  # (p,d,q)
model_fit = model.fit()

y_pred_boxcox_diff = model_fit.forecast(steps=len(test))
# Out:
# /Users/akshat31/Development/CryptoChakra/crypto-env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:3437: RuntimeWarning: divide by zero encountered in matmul
#   return _core_matmul(x1, x2)
# /Users/akshat31/Development/CryptoChakra/crypto-env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:3437: RuntimeWarning: overflow encountered in matmul
#   return _core_matmul(x1, x2)
# /Users/akshat31/Development/CryptoChakra/crypto-env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:3437: RuntimeWarning: invalid value encountered in matmul
#   return _core_matmul(x1, x2)

# %%
# Invert log to get actual price forecast
last_known = df_features['BoxCox_Close'].iloc[train_len - 1]

# Reconstruct full Box-Cox values from diffs
y_pred_boxcox = np.r_[last_known, y_pred_boxcox_diff].cumsum()

y_pred_original = inv_boxcox(y_pred_boxcox, lambda_bc)

# Align test true values
actual_prices = df_features['Close'].iloc[train_len:train_len + len(y_pred_original)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 11
#       9 # Align test true values
#      10 actual_prices = df_features['Close'].iloc[train_len:train_len + len(y_pred_original)]
# ---> 11 y_pred_original.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %% [markdown]
# ### Step 5: Analyze accuracy using different metrics

# %%
mae = mean_absolute_error(actual_prices, y_pred_original)
mape = mean_absolute_percentage_error(actual_prices, y_pred_original)
rmse = np.sqrt(mean_squared_error(actual_prices, y_pred_original))
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2%}")
# Out:
# RMSE: 24991.94
# MAE: 18420.88
# MAPE: 26.91%

# %%
plt.figure(figsize=(10, 5))
plt.plot(actual_prices.index, actual_prices.values, label="Actual")
plt.plot(actual_prices.index, y_pred_original, label="Forecast")
plt.title("ARIMA(1,1,1) Bitcoin Price Forecast")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ARIMA predictions for Bitcoin tend to have a bad reputation and a high error value since these models cannot learn the non-linear relationships in the cryptocurrency data. ARIMA also assumes a linear relationship between past and future data, which may not always be true for this market. ARIMA also considers only one feature i.e. the past closing prices. Not considering other qualitative ƒactors like market sentiment and other technical indicators make it a weak model. Bitcoin data is non-stationary as well and differencing might remove meaningful patterns in this data.

# %% [markdown]
# ### Checking training accuracy

# %%
forecast_log_train = model_fit.predict(start=1, end=train_len - 1)

log_start = train.iloc[0]
forecast_log_price = log_start + forecast_log_train.cumsum()

# Convert to actual price scale
forecast_prices_train = np.exp(forecast_log_price)

# %%
plt.figure(figsize=(12, 5))
plt.plot(df_features['Close'].iloc[1:len(forecast_prices_train)+1], label='Actual (Train)')
plt.plot(forecast_prices_train.index, forecast_prices_train.values, label='ARIMA Fit (Train)', linestyle='--')
plt.title('In-Sample ARIMA(1,1,1) Fit')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model Building II: LSTM

# %%
df_lstm = df_features.copy()
df_lstm.dropna(inplace=True)

# %% [markdown]
# ### Step 1: Prepare the training and testing data by creating sequences

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Fit separately
scaled_features = feature_scaler.fit_transform(df_lstm)
scaled_target = target_scaler.fit_transform(df_lstm[['Close']])

def create_sequences(X, y, time_steps=30):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 30
X, y = create_sequences(scaled_features, scaled_target, time_steps)


X_train, X_test = X[:train_len], X[train_len:]
y_train, y_test = y[:train_len], y[train_len:]

# %% [markdown]
# ### Step 2: Configure and create the model

# %%
model = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    LSTM(32),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 30, 64)         │        26,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,385 (157.75 KB)
#  Trainable params: 40,385 (157.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 3: Training and Prediction

# %%
# Train with early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=100, batch_size=32,
                    validation_split=0.1, callbacks=[early_stop], verbose=1)

# Predict and inverse scale
y_pred = model.predict(X_test)
y_pred_inv = target_scaler.inverse_transform(y_pred)
y_test_inv = target_scaler.inverse_transform(y_test)
# Out:
# Epoch 1/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0068 - val_loss: 5.7728e-04
# Epoch 2/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.4340e-04 - val_loss: 8.0968e-04
# Epoch 3/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.4816e-04 - val_loss: 0.0048
# Epoch 4/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.1387e-04 - val_loss: 4.9032e-04
# Epoch 5/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6848e-04 - val_loss: 4.7654e-04
# Epoch 6/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7268e-04 - val_loss: 5.3107e-04
# Epoch 7/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5829e-04 - val_loss: 3.2310e-04
# Epoch 8/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7338e-04 - val_loss: 5.6194e-04
# Epoch 9/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.4685e-04 - val_loss: 8.1913e-04
# Epoch 10/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1393e-04 - val_loss: 2.7901e-04
# Epoch 11/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2129e-04 - val_loss: 9.7069e-04
# Epoch 12/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.5819e-04 - val_loss: 4.5358e-04
# Epoch 13/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.9502e-05 - val_loss: 3.0290e-04
# Epoch 14/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3094e-04 - val_loss: 2.3485e-04
# Epoch 15/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.8337e-05 - val_loss: 6.1855e-04
# Epoch 16/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1710e-04 - val_loss: 3.6003e-04
# Epoch 17/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.5322e-05 - val_loss: 4.9486e-04
# Epoch 18/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.9888e-05 - val_loss: 2.5031e-04
# Epoch 19/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.6130e-05 - val_loss: 2.7188e-04
# Epoch 20/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1448e-04 - val_loss: 2.0881e-04
# Epoch 21/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9336e-05 - val_loss: 4.5049e-04
# Epoch 22/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0466e-04 - val_loss: 2.0159e-04
# Epoch 23/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.4005e-05 - val_loss: 2.1574e-04
# Epoch 24/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.0181e-05 - val_loss: 0.0012
# Epoch 25/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.5652e-05 - val_loss: 2.1375e-04
# Epoch 26/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.9628e-05 - val_loss: 2.7878e-04
# Epoch 27/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.9646e-05 - val_loss: 2.5507e-04
# Epoch 28/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.3558e-05 - val_loss: 2.3052e-04
# Epoch 29/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.9218e-05 - val_loss: 1.4888e-04
# Epoch 30/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9717e-05 - val_loss: 2.3522e-04
# Epoch 31/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.0009e-05 - val_loss: 5.9742e-04
# Epoch 32/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.5897e-05 - val_loss: 5.1598e-04
# Epoch 33/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.2492e-05 - val_loss: 1.5862e-04
# Epoch 34/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.9211e-05 - val_loss: 3.5513e-04
# Epoch 35/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.3334e-05 - val_loss: 1.8117e-04
# Epoch 36/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9825e-05 - val_loss: 1.7742e-04
# Epoch 37/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5747e-05 - val_loss: 2.0965e-04
# Epoch 38/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.2634e-05 - val_loss: 4.8672e-04
# Epoch 39/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.5366e-05 - val_loss: 1.2712e-04
# Epoch 40/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.3371e-05 - val_loss: 1.4007e-04
# Epoch 41/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.5071e-05 - val_loss: 1.7730e-04
# Epoch 42/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.6211e-05 - val_loss: 2.4047e-04
# Epoch 43/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.7720e-05 - val_loss: 3.1856e-04
# Epoch 44/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.6855e-05 - val_loss: 2.1097e-04
# Epoch 45/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.9034e-05 - val_loss: 4.5680e-04
# Epoch 46/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9916e-05 - val_loss: 1.2929e-04
# Epoch 47/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5458e-05 - val_loss: 3.2047e-04
# Epoch 48/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.1343e-05 - val_loss: 3.2061e-04
# Epoch 49/100
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.6614e-05 - val_loss: 1.4310e-04
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ### Step 4: Accuracy Analysis

# %%
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv)

print(f"Test MAE: {mae:.2f}")
print(f"Test MAPE: {mape:.2%}")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted', linestyle='--')
plt.title("LSTM - Bitcoin Price Prediction")
plt.legend()
plt.grid()
plt.show()
# Out:
# Test MAE: 4161.01
# Test MAPE: 5.65%

# %% [markdown]
# The LSTM does really well on unseen test data, much lower error values compared to ARIMA. This is because LSTM uses a lot more features to better predict the price movement of the asset, and it also can learn non-linear relationships really well. We can experiment with hyperparameter tuning to change the sequence length , dropout rate, and even the layers and number of neurons to check if we can get a better model.
# Currently we use a 30 day sequence window since a month is a reasonable time to capture relevant patterns and sudden price movements.
# The dropout rate is 20% for the LSTM for adding noise to the data and to prevent it from overfitting. It is sort of a regularizer for the model that randomly drops 20% of the output during training.
# The reduction of neurons in the second LSTM layer from 64 to 32 helps compress and capture the essential information in the data, and reducing the neurons help reduce overfitting.
# The final fully connected layer with RelU is for nonlinear transformation and feature mixing.

# %%
# Predict and inverse scale
y_pred = model.predict(X_train)
y_pred_inv = target_scaler.inverse_transform(y_pred)
y_test_inv = target_scaler.inverse_transform(y_test)


mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv)

print(f"Test MAE: {mae:.2f}")
print(f"Test MAPE: {mape:.2%}")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted', linestyle='--')
plt.title("LSTM - Bitcoin Price Prediction")
plt.legend()
plt.grid()
plt.show()
